# %% [markdown]
# # 부산 지하철 이용객 분석

# %% [markdown]
# ### **링크 기록**
# - [부산데이터 홈페이지](https://data.busan.go.kr/) 접속
# - 승하차 인원 검색(시간대별 승하차 인원 - 20240930.csv)

# %% [markdown]
# ### 3대장 분석기
# 1. *matplotlib* = 시각화도구
# 2. *pandas* = 데이터프레임
# 3. *(numpy)* = 숫자,행렬

# %%
# !pip install matplotlib
# !pip install pandas
# !pip install squarify
# !pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-2.2.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\penta\appdata\roaming\python\python313\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\penta\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\penta\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.3-cp313-cp313-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ------- -------------------------------- 2.1/11.5 MB 11.7 MB/s eta 0:00:01
#    -------------- ------------------------- 4.2/11.5 MB 11.1 MB/s eta 0:00:01
#    ------------------------- -------------- 7.3/11.5 MB 12.2 MB/s eta 0:00:01
#    -------------------------------------- - 11.0/11.5 MB 13.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 12.1 MB/s eta 0:00:00
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.3 pytz-2024.2 tzdata-2024.2

# %%
# 시각화 도구
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 데이터 프레임
import pandas as pd

# import squartify

# %% [markdown]
# ### 차트 스타일

# %%
# 차트 스타일
plt.style.use('fivethirtyeight')
# 폰트 설정
d2coding_path = 'D2Coding/D2Coding-Ver1.3.2-20180524.ttf'
fm.fontManager.addfont(d2coding_path)
plt.rcParams['font.family'] = 'D2Coding'

# 마이너스 부호 설정
matplotlib.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 데이터 불러오기

# %%
file_path = '../dataset/일별 역별 시간대별 승하차(2024년 5월).csv'
data = pd.read_csv(file_path, encoding='EUC-KR')
data.columns
# Out:
# Index(['역번호', '역명', '년월일', '요일', '구분', '합계', '01시-02시', '02시-03시', '03시-04시',
#        '04시-05시', '05시-06시', '06시-07시', '07시-08시', '08시-09시', '09시-10시',
#        '10시-11시', '11시-12시', '12시-13시', '13시-14시', '14시-15시', '15시-16시',
#        '16시-17시', '17시-18시', '18시-19시', '19시-20시', '20시-21시', '21시-22시',
#        '22시-23시', '23시-24시', '24시-01시'],
#       dtype='object')

# %%
columns = ['num', 'stationName', 'date', 'week', 'type', 'total']
time_tab_col = [ f'{i}H~{i+1}H' for i in range(1, 24) ] + ['24~1H']
columns += time_tab_col
# print(columns)

# %%
# sets = pd.Index(columns)
# print(sets)
data.columns = columns
data.head()
# Out:
#    num stationName        date week type  total  1H~2H  2H~3H  3H~4H  4H~5H  \
# 0   95     다대포해수욕장  2024-01-01    월   승차   8587      0      0      0     12
# 1   95     다대포해수욕장  2024-01-01    월   하차   8377      0      4      0      1
# 2   95     다대포해수욕장  2024-01-02    화   승차   4882      0      1      1     16
# 3   95     다대포해수욕장  2024-01-02    화   하차   4056      2      0      0      2
# 4   95     다대포해수욕장  2024-01-03    수   승차   4663      0      0      0     20
#
#    ...  15H~16H  16H~17H  17H~18H  18H~19H  19H~20H  20H~21H  21H~22H  \
# 0  ...      585      537      468      266      162       84      111
# 1  ...      363      369      303      192      127       92       97
# 2  ...      458      422      374      221      142       85       72
# 3  ...      339      325      281      362      253      135      120
# 4  ...      369      303      358      241      115       91       70
#
#    22H~23H  23H~24H  24~1H
# 0       70       16      0
# 1       54       42     31
# 2       50       14      0
# 3       94       90     53
# 4       70       17      0
#
# [5 rows x 30 columns]

# %%
# gdata = data.groupby(['num', 'stationName', 'week', 'date']).sum() # 그룹 후 승하차 구분 하나로 합산
gdata = data.groupby(['num', 'stationName', 'week', 'date']).sum().reset_index() # 합산 후 인덱스 초기화
# gdata.head()
gdata[gdata['date']=='2024-05-01']
# gdata['date']=='2024-01-01'
# Out:
#        num stationName week        date  type  total  1H~2H  2H~3H  3H~4H  \
# 61      95     다대포해수욕장    수  2024-05-01  승차하차   9613      0      3      0
# 213     96        다대포항    수  2024-05-01  승차하차   6791      0      0      0
# 365     97          낫개    수  2024-05-01  승차하차   8757      0      0      0
# 517     98         신장림    수  2024-05-01  승차하차   5730      0      0      0
# 669     99          장림    수  2024-05-01  승차하차   7249      0      0      0
# ...    ...         ...  ...         ...   ...    ...    ...    ...    ...
# 16325  410          석대    수  2024-05-01  승차하차    334      0      0      0
# 16477  411         영산대    수  2024-05-01  승차하차   5094      0      0      0
# 16629  412         윗반송    수  2024-05-01  승차하차   4743      0      0      0
# 16781  413          고촌    수  2024-05-01  승차하차   1100      0      0      0
# 16933  414          안평    수  2024-05-01  승차하차   3564      0      0      0
#
#        4H~5H  ...  15H~16H  16H~17H  17H~18H  18H~19H  19H~20H  20H~21H  \
# 61        15  ...      850      859      661      469      402      325
# 213        8  ...      586      550      501      461      254      203
# 365       19  ...      645      690      706      627      361      340
# 517        4  ...      434      471      409      322      240      192
# 669        7  ...      620      597      538      457      235      222
# ...      ...  ...      ...      ...      ...      ...      ...      ...
# 16325      0  ...       33       19       14       19       10        2
# 16477      4  ...      346      385      421      293      160      160
# 16629     13  ...      344      340      376      278      187      118
# 16781      3  ...       69       89       80       78       43       32
# 16933      3  ...      244      314      284      256      124      123
#
#        21H~22H  22H~23H  23H~24H  24~1H
# 61         241      181      112     57
# 213        182      147       67     23
# 365        287      234      173     45
# 517        139      132      100     25
# 669        311      143      102     28
# ...        ...      ...      ...    ...
# 16325        1        2        0      4
# 16477      115      118       89     30
# 16629      109       71       41     28
# 16781       14       16        3      4
# 16933       91       76       39     21
#
# [112 rows x 30 columns]

# %%
# 각 역마다 일자별 정리
mdata = gdata[gdata['date']>='2024-05-01'][gdata['total']>=20000][['stationName', 'date', 'total', 'week']]
mdata = mdata.sort_values(by=['stationName', 'date'], ascending=[1, 0])
mdata.head()
# Out:
# C:\Users\penta\AppData\Local\Temp\ipykernel_19076\1459019961.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   mdata = gdata[gdata['date']>='2024-05-01'][gdata['total']>=20000][['stationName', 'date', 'total', 'week']]
#      stationName        date  total week
# 9445          개금  2024-05-31  20193    금
# 9575          개금  2024-05-28  20227    화
# 9511          개금  2024-05-27  20025    월
# 9574          개금  2024-05-21  20306    화
# 9443          개금  2024-05-17  20363    금

# %%
# 데이터 날짜별로 통합
date = gdata[gdata['date']>='2024-05-01'].sort_values(by=['date', 'total', 'stationName'], ascending=[True, False, True])[['stationName', 'date', 'total']]
date.head(10)
# Out:
#       stationName        date  total
# 3709           서면  2024-05-01  76528
# 8877           서면  2024-05-01  51667
# 2493           남포  2024-05-01  41463
# 2797          부산역  2024-05-01  39972
# 10093          사상  2024-05-01  39086
# 2341          자갈치  2024-05-01  38496
# 6901         센텀시티  2024-05-01  34972
# 1125           하단  2024-05-01  34667
# 3861           부전  2024-05-01  34315
# 5077          부산대  2024-05-01  32972

# %%
# 역이름 기준으로 날짜 통합 + total 합치기
total = gdata[gdata['date']>='2024-05-01'].groupby(['stationName']).sum().sort_values(by='total',ascending=False).reset_index()[['stationName', 'total']]
total.head(20)
# Out:
#    stationName    total
# 0           서면  3910687
# 1           연산  1713640
# 2          부산역  1508595
# 3           사상  1417385
# 4           동래  1255221
# 5           남포  1225592
# 6         센텀시티  1221757
# 7           하단  1219325
# 8          자갈치  1155917
# 9       경성대부경대  1151742
# 10          덕천  1112330
# 11          부전  1105656
# 12         부산대  1053939
# 13          수영   951180
# 14         온천장   947844
# 15          범일   945540
# 16          장산   933937
# 17         해운대   919707
# 18          시청   914707
# 19          교대   894907

# %%
from IPython.display import display, HTML

# %%
display(HTML(f'''
<div style='display: flex; font-size: 2rem; color: skyblue; column-gap: 0.5rem; background: #404; width: 180px; justify-content: center;'><a>aaa</a><a>bbb</a><a>ccc</a></div>
'''))
# Out:
# <div style='display: flex; font-size: 2rem; color: skyblue; column-gap: 0.5rem; background: #404; width: 180px; justify-content: center;'><a>aaa</a><a>bbb</a><a>ccc</a></div>

# %%
display(HTML(f'''
<div style='display: flex;'>
<div style='flex: 1; padding: 10px;'><h3>Total Popular</h3>{total.head(20).to_html(index=0)}</div>
<div style='flex: 1; padding: 10px;'><h3>Date Popular</h3>{date.head(20).to_html(index=0)}</div>
</div>
'''))
# Out:
# <div style='display: flex;'>
# <div style='flex: 1; padding: 10px;'><h3>Total Popular</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>stationName</th>
#       <th>total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>서면</td>
#       <td>3910687</td>
#     </tr>
#     <tr>
#       <td>연산</td>
#       <td>1713640</td>
#     </tr>
#     <tr>
#       <td>부산역</td>
#       <td>1508595</td>
#     </tr>
#     <tr>
#       <td>사상</td>
#       <td>1417385</td>
#     </tr>
#     <tr>
#       <td>동래</td>
#       <td>1255221</td>
#     </tr>
#     <tr>
#       <td>남포</td>
#       <td>1225592</td>
#     </tr>
#     <tr>
#       <td>센텀시티</td>
#       <td>1221757</td>
#     </tr>
#     <tr>
#       <td>하단</td>
#       <td>1219325</td>
#     </tr>
#     <tr>
#       <td>자갈치</td>
#       <td>1155917</td>
#     </tr>
#     <tr>
#       <td>경성대부경대</td>
#       <td>1151742</td>
#     </tr>
#     <tr>
#       <td>덕천</td>
#       <td>1112330</td>
#     </tr>
#     <tr>
#       <td>부전</td>
#       <td>1105656</td>
#     </tr>
#     <tr>
#       <td>부산대</td>
#       <td>1053939</td>
#     </tr>
#     <tr>
#       <td>수영</td>
#       <td>951180</td>
#     </tr>
#     <tr>
#       <td>온천장</td>
#       <td>947844</td>
#     </tr>
#     <tr>
#       <td>범일</td>
#       <td>945540</td>
#     </tr>
#     <tr>
#       <td>장산</td>
#       <td>933937</td>
#     </tr>
#     <tr>
#       <td>해운대</td>
#       <td>919707</td>
#     </tr>
#     <tr>
#       <td>시청</td>
#       <td>914707</td>
#     </tr>
#     <tr>
#       <td>교대</td>
#       <td>894907</td>
#     </tr>
#   </tbody>
# </table></div>
# <div style='flex: 1; padding: 10px;'><h3>Date Popular</h3><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>stationName</th>
#       <th>date</th>
#       <th>total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>서면</td>
#       <td>2024-05-01</td>
#       <td>76528</td>
#     </tr>
#     <tr>
#       <td>서면</td>
#       <td>2024-05-01</td>
#       <td>51667</td>
#     </tr>
#     <tr>
#       <td>남포</td>
#       <td>2024-05-01</td>
#       <td>41463</td>
#     </tr>
#     <tr>
#       <td>부산역</td>
#       <td>2024-05-01</td>
#       <td>39972</td>
#     </tr>
#     <tr>
#       <td>사상</td>
#       <td>2024-05-01</td>
#       <td>39086</td>
#     </tr>
#     <tr>
#       <td>자갈치</td>
#       <td>2024-05-01</td>
#       <td>38496</td>
#     </tr>
#     <tr>
#       <td>센텀시티</td>
#       <td>2024-05-01</td>
#       <td>34972</td>
#     </tr>
#     <tr>
#       <td>하단</td>
#       <td>2024-05-01</td>
#       <td>34667</td>
#     </tr>
#     <tr>
#       <td>부전</td>
#       <td>2024-05-01</td>
#       <td>34315</td>
#     </tr>
#     <tr>
#       <td>부산대</td>
#       <td>2024-05-01</td>
#       <td>32972</td>
#     </tr>
#     <tr>
#       <td>동래</td>
#       <td>2024-05-01</td>
#       <td>31836</td>
#     </tr>
#     <tr>
#       <td>경성대부경대</td>
#       <td>2024-05-01</td>
#       <td>30621</td>
#     </tr>
#     <tr>
#       <td>연산</td>
#       <td>2024-05-01</td>
#       <td>29743</td>
#     </tr>
#     <tr>
#       <td>해운대</td>
#       <td>2024-05-01</td>
#       <td>28312</td>
#     </tr>
#     <tr>
#       <td>시청</td>
#       <td>2024-05-01</td>
#       <td>28115</td>
#     </tr>
#     <tr>
#       <td>수영</td>
#       <td>2024-05-01</td>
#       <td>27445</td>
#     </tr>
#     <tr>
#       <td>범일</td>
#       <td>2024-05-01</td>
#       <td>27437</td>
#     </tr>
#     <tr>
#       <td>온천장</td>
#       <td>2024-05-01</td>
#       <td>27031</td>
#     </tr>
#     <tr>
#       <td>장산</td>
#       <td>2024-05-01</td>
#       <td>26745</td>
#     </tr>
#     <tr>
#       <td>교대</td>
#       <td>2024-05-01</td>
#       <td>24187</td>
#     </tr>
#   </tbody>
# </table></div>
# </div>

# %% [markdown]
# ## 시각화

# %%
import squarify

plt.figure(figsize=(20, 15))
squarify.plot(sizes=total['total'], label=total.stationName, alpha=0.8)
plt.gca().invert_yaxis()
plt.axis('off')
plt.show()

# %% [markdown]
# ## 숙제(수도권 도시철도 데이터)

# %%
file_path = '../dataset/서울교통공사_역별 일별 시간대별 승하차인원 정보_20231231.csv'
data = pd.read_csv(file_path, encoding='EUC-KR')
data.columns
# Out:
# Index(['연번', '수송일자', '호선', '역번호', '역명', '승하차구분', '06시이전', '06-07시간대',
#        '07-08시간대', '08-09시간대', '09-10시간대', '10-11시간대', '11-12시간대', '12-13시간대',
#        '13-14시간대', '14-15시간대', '15-16시간대', '16-17시간대', '17-18시간대', '18-19시간대',
#        '19-20시간대', '20-21시간대', '21-22시간대', '22-23시간대', '23-24시간대', '24시이후'],
#       dtype='object')

# %%
columns = ['id', 'date', 'lineNum', 'stationNum', 'stationName', 'type']
time_tab_col = ['~6H'] + [ f'{i}H~{i+1}H' for i in range(6, 24) ] + ['24H~']
columns += time_tab_col
data.columns = columns
data['total'] = data[time_tab_col].sum(axis=1)

# %%
data.head(20)
# Out:
#     id        date lineNum  stationNum   stationName type  ~6H  6H~7H  7H~8H  \
# 0    1  2023-01-01     1호선         150           서울역   승차  215    145    231
# 1    2  2023-01-01     1호선         150           서울역   하차  154    636    595
# 2    3  2023-01-01     1호선         151            시청   승차   48     73    106
# 3    4  2023-01-01     1호선         151            시청   하차   64    247    293
# 4    5  2023-01-01     1호선         152            종각   승차  407    235    158
# 5    6  2023-01-01     1호선         152            종각   하차   69    164    268
# 6    7  2023-01-01     1호선         153          종로3가   승차  220    171    121
# 7    8  2023-01-01     1호선         153          종로3가   하차   39    118    130
# 8    9  2023-01-01     1호선         154          종로5가   승차   46     48     79
# 9   10  2023-01-01     1호선         154          종로5가   하차   26     84    130
# 10  11  2023-01-01     1호선         155           동대문   승차  152    116    106
# 11  12  2023-01-01     1호선         155           동대문   하차   32    119    148
# 12  13  2023-01-01     1호선         156           신설동   승차  102    104    138
# 13  14  2023-01-01     1호선         156           신설동   하차   38    126    128
# 14  15  2023-01-01     1호선         157           제기동   승차   88     96    129
# 15  16  2023-01-01     1호선         157           제기동   하차   33    100     91
# 16  17  2023-01-01     1호선         158  청량리(서울시립대입구)   승차  147    132    169
# 17  18  2023-01-01     1호선         158  청량리(서울시립대입구)   하차   45    142    150
# 18  19  2023-01-01     1호선         159           동묘앞   승차   34     43     83
# 19  20  2023-01-01     1호선         159           동묘앞   하차   31    103    105
#
#     8H~9H  ...  16H~17H  17H~18H  18H~19H  19H~20H  20H~21H  21H~22H  22H~23H  \
# 0     594  ...     2509     2696     2549     2462     2177     2190     1808
# 1     939  ...     2295     2526     1930     1897     1487      991      609
# 2     194  ...      895      959      985      670      630      515      330
# 3     463  ...      575      533      456      285      267      246      154
# 4     201  ...     1402     1223     1272      911      913      906      602
# 5     384  ...      890      807      564      391      267      207      149
# 6     155  ...     1392     1338     1080      879      763      664      477
# 7     274  ...      839      621      454      316      227      201      122
# 8     101  ...     1010     1020      875      592      572      382      177
# 9     216  ...      742      592      438      304      195      174      152
# 10    194  ...      938      670      500      437      285      283      201
# 11    224  ...      460      490      401      344      274      289      261
# 12    197  ...      614      513      359      246      181      163      101
# 13    179  ...      443      420      393      363      344      356      261
# 14    188  ...      891      686      548      460      279      146       96
# 15    177  ...      617      567      402      298      274      268      182
# 16    264  ...     1059      857      649      462      358      251      148
# 17    234  ...      771      712      561      446      397      360      295
# 18    105  ...     1515      929      423      197      104       82       63
# 19    193  ...      600      285      177      192      153      164      170
#
#     23H~24H  24H~  total
# 0       734     7  32023
# 1       280    46  27044
# 2       146     0   9317
# 3        79    18   8300
# 4       232     3  13019
# 5       136    15  10791
# 6       163     6  13016
# 7        90    31  10898
# 8        65     0   9878
# 9        95    10   9018
# 10      112     8   8897
# 11      167    24   8585
# 12       61     7   6383
# 13      235    48   6591
# 14       26     3   8121
# 15      149    29   8665
# 16       71     0  10191
# 17      193    76  10303
# 18       38     0  10027
# 19      113    41  10217
#
# [20 rows x 27 columns]

# %%
data[data['total']==0]
# Out:
#             id        date lineNum  stationNum stationName type  ~6H  6H~7H  \
# 144        145  2023-01-01     3호선         321         충무로   승차    0      0
# 145        146  2023-01-01     3호선         321         충무로   하차    0      0
# 360        361  2023-01-01     6호선        2615         연신내   승차    0      0
# 361        362  2023-01-01     6호선        2615         연신내   하차    0      0
# 1236      1237  2023-01-03     3호선         321         충무로   승차    0      0
# ...        ...         ...     ...         ...         ...  ...  ...    ...
# 197991  197992  2023-12-29     6호선        2615         연신내   하차    0      0
# 198322  198323  2023-12-30     3호선         321         충무로   승차    0      0
# 198323  198324  2023-12-30     3호선         321         충무로   하차    0      0
# 198868  198869  2023-12-31     3호선         321         충무로   승차    0      0
# 198869  198870  2023-12-31     3호선         321         충무로   하차    0      0
#
#         7H~8H  8H~9H  ...  16H~17H  17H~18H  18H~19H  19H~20H  20H~21H  \
# 144         0      0  ...        0        0        0        0        0
# 145         0      0  ...        0        0        0        0        0
# 360         0      0  ...        0        0        0        0        0
# 361         0      0  ...        0        0        0        0        0
# 1236        0      0  ...        0        0        0        0        0
# ...       ...    ...  ...      ...      ...      ...      ...      ...
# 197991      0      0  ...        0        0        0        0        0
# 198322      0      0  ...        0        0        0        0        0
# 198323      0      0  ...        0        0        0        0        0
# 198868      0      0  ...        0        0        0        0        0
# 198869      0      0  ...        0        0        0        0        0
#
#         21H~22H  22H~23H  23H~24H  24H~  total
# 144           0        0        0     0      0
# 145           0        0        0     0      0
# 360           0        0        0     0      0
# 361           0        0        0     0      0
# 1236          0        0        0     0      0
# ...         ...      ...      ...   ...    ...
# 197991        0        0        0     0      0
# 198322        0        0        0     0      0
# 198323        0        0        0     0      0
# 198868        0        0        0     0      0
# 198869        0        0        0     0      0
#
# [682 rows x 27 columns]

# %%
# data['total'] = data[time_tab_col].sum(axis=1)

# %%
gdata = data.groupby(['stationNum', 'lineNum', 'stationName']).sum().reset_index()[['stationNum', 'lineNum', 'stationName', 'total']] # 합산 후 인덱스 초기화
gdata.head(20)
# Out:
#     stationNum lineNum     stationName     total
# 0          150     1호선             서울역  36716140
# 1          151     1호선              시청  17950406
# 2          152     1호선              종각  25984471
# 3          153     1호선            종로3가  18040693
# 4          154     1호선            종로5가  17337323
# 5          155     1호선             동대문   8355108
# 6          156     1호선             신설동   9530294
# 7          157     1호선             제기동  12252199
# 8          158     1호선    청량리(서울시립대입구)  14717395
# 9          159     1호선             동묘앞   7190419
# 10         201     2호선              시청  16661470
# 11         202     2호선           을지로입구  32584659
# 12         203     2호선           을지로3가  16417881
# 13         204     2호선           을지로4가   9494391
# 14         205     2호선  동대문역사문화공원(DDP)  11295490
# 15         206     2호선              신당  10470320
# 16         207     2호선            상왕십리   9752772
# 17         208     2호선       왕십리(성동구청)  10570877
# 18         209     2호선             한양대   7892999
# 19         210     2호선              뚝섬  16650581

# %%
su_total = gdata[gdata['total']>0].sort_values(by=['total', 'stationNum'], ascending=[False, True]).reset_index()
#.merge(gdata[time_tab_col])
# su_total.head(50)
su_total.tail(15)
# Out:
#      index  stationNum lineNum     stationName    total
# 258    199        2634     6호선              약수  2591577
# 259    167        2558     5호선              오금  2476965
# 260    203        2638     6호선              창신  2276207
# 261    146        2537     5호선  동대문역사문화공원(DDP)  2221882
# 262     53         244     2호선              용답  2161673
# 263    179        2614     6호선             독바위  1989248
# 264     87         336     3호선             학여울  1778216
# 265     59         250     2호선       용두(동대문구청)  1722031
# 266    198        2633     6호선            버티고개  1528510
# 267    116         431     4호선         동작(현충원)  1461274
# 268    215        2711     7호선              장암  1328704
# 269     54         245     2호선              신답  1222015
# 270     56         247     2호선             도림천   911586
# 271    119         434     4호선             남태령   899824
# 272     72         321     3호선             충무로      242

# %%
import squarify

plt.figure(figsize=(30, 24))
squarify.plot(sizes=su_total['total'], label=su_total.stationName, alpha=0.6)
plt.gca().invert_yaxis()
plt.axis('off')
plt.show()
