# %% [markdown]
# ## 교통사고 유형별 분석

# %% [markdown]
# 데이터 준비<br />
# <a href='https://www.data.go.kr/data/15029185/standard.do'>공공데이터 교통사고 유형</a>

# %%
# !pip install folium

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

import pandas as pd
import squarify

# %%
plt.style.use('fivethirtyeight')

d2coding_path = 'D2Coding/D2Coding-Ver1.3.2-20180524.ttf' # 폰트 경로
fm.fontManager.addfont(d2coding_path)
plt.rcParams['font.family'] = 'D2Coding'

matplotlib.rcParams['axes.unicode_minus'] = False

# %%
file_path = '../dataset/전국교통사고다발지역표준데이터.csv'
data_ori = pd.read_csv(file_path, encoding='EUC-KR')
data_ori.columns
# Out:
# Index(['사고지역관리번호', '사고연도', '사고유형구분', '위치코드', '사고다발지역시도시군구', '사고지역위치명', '사고건수',
#        '사상자수', '사망자수', '중상자수', '경상자수', '부상신고자수', '위도', '경도', '사고다발지역폴리곤정보',
#        '데이터기준일자', '제공기관코드', '제공기관명'],
#       dtype='object')

# %%
data_ori[['사고지역관리번호', '사고연도', '사고유형구분', '위치코드', '사고다발지역시도시군구', '사고건수', '사상자수', '부상신고자수', '사고지역위치명']]
# Out:
#        사고지역관리번호  사고연도 사고유형구분      위치코드  사고다발지역시도시군구  사고건수  사상자수  부상신고자수  \
# 0       2021030  2020   무단횡단  15134300     충북 청주흥덕1     4     4       0
# 1       2021030  2020   무단횡단  16044400       충남 서산1     5     5       0
# 2       2021030  2020   무단횡단  16054400     충남 천안서북1     5     6       0
# 3       2021030  2020   무단횡단  16054400     충남 천안서북2     5     6       0
# 4       2021030  2020   무단횡단  16054400     충남 천안서북3     4     5       0
# ...         ...   ...    ...       ...          ...   ...   ...     ...
# 14473   2015046  2014    자전거  11710010  서울특별시 송파구10     8     8       4
# 14474   2015046  2014    자전거  11710011  서울특별시 송파구11     7     8       0
# 14475   2015046  2014    자전거  11710012  서울특별시 송파구12     7     7       1
# 14476   2015046  2014    자전거  11710013  서울특별시 송파구13     7     7       3
# 14477   2015046  2014    자전거  11710014  서울특별시 송파구14     6     6       1
#
#                                   사고지역위치명
# 0               충청북도 청주시 흥덕구 봉명동(은파교회 부근)
# 1                   충청남도 서산시 석림동(하트리움 부근)
# 2          충청남도 천안시 서북구 성정동(엔제리너스천안성정 부근)
# 3               충청남도 천안시 서북구 성정동(LG천막 부근)
# 4               충청남도 천안시 서북구 두정동(플라리안 부근)
# ...                                   ...
# 14473             서울특별시 송파구 거여동(마천사거리 부근)
# 14474  서울특별시 송파구 신천동(잠실역_일반국도3호선_진입_1 부근)
# 14475              서울특별시 송파구 삼전동(신양빌라 부근)
# 14476           서울특별시 송파구 가락동(문정시영아파트 부근)
# 14477             서울특별시 송파구 풍납동(천호사거리 부근)
#
# [14478 rows x 9 columns]

# %%
data_pick = data_ori[['사고연도', '사고유형구분', '사고다발지역시도시군구', '사고지역위치명', '사고건수', '위도', '경도', '사고다발지역폴리곤정보']]
data_pick.head()
# Out:
#    사고연도 사고유형구분 사고다발지역시도시군구                         사고지역위치명  사고건수         위도  \
# 0  2020   무단횡단    충북 청주흥덕1       충청북도 청주시 흥덕구 봉명동(은파교회 부근)     4  36.650390
# 14458  37.524358  127.015378
# 14459  37.492323  127.083538
# 14460  37.497138  127.045338
# 14461  37.478874  127.049105
# 14462  37.492384  127.058243
# 14463  37.496716  127.054352
# 14464  37.518233  127.081505
# 14465  37.502317  127.096595
# 14466  37.493047  127.117271
# 14467  37.513135  127.128650
# 14468  37.507464  127.090808
# 14469  37.506512  127.097081
# 14470  37.508745  127.126188
# 14471  37.516832  127.114175
# 14472  37.515939  127.108374
# 14473  37.497152  127.146265
# 14474  37.514094  127.099354
# 14475  37.501233  127.085015
# 14476  37.492374  127.136029
# 14477  37.538616  127.123464
#
#                                                  polygon
# 14458  {type:Polygon,coordinates:[[[127.0169778,37.52...
# 14459  {type:Polygon,coordinates:[[[127.0851367,37.49...
# 14460  {type:Polygon,coordinates:[[[127.0469368,37.49...
# 14461  {type:Polygon,coordinates:[[[127.0507036,37.48...
# 14462  {type:Polygon,coordinates:[[[127.0598422,37.49...
# 14463  {type:Polygon,coordinates:[[[127.0559513,37.49...
# 14464  {type:Polygon,coordinates:[[[127.0831043,37.51...
# 14465  {type:Polygon,coordinates:[[[127.0981948,37.50...
# 14466  {type:Polygon,coordinates:[[[127.1188702,37.49...
# 14467  {type:Polygon,coordinates:[[[127.1302499,37.51...
# 14468  {type:Polygon,coordinates:[[[127.0924074,37.50...
# 14469  {type:Polygon,coordinates:[[[127.0986808,37.50...
# 14470  {type:Polygon,coordinates:[[[127.1277876,37.51...
# 14471  {type:Polygon,coordinates:[[[127.1157748,37.51...
# 14472  {type:Polygon,coordinates:[[[127.1099741,37.51...
# 14473  {type:Polygon,coordinates:[[[127.1478646,37.49...
# 14474  {type:Polygon,coordinates:[[[127.1009533,37.51...
# 14475  {type:Polygon,coordinates:[[[127.0866148,37.50...
# 14476  {type:Polygon,coordinates:[[[127.1376285,37.49...
# 14477  {type:Polygon,coordinates:[[[127.1250644,37.53...

# %%
data_pick['region'] = data_pick['region'].str.replace(r'\d+', '', regex = 1)
data_pick.sample(15)
# Out:
#        year    type       region                        street  accidents  \
# 2554   2017    보행노인     충청남도 서천군        충청남도 서천군 서천읍(서천한의원 부근)          4
# 10178  2020    보행노인     인천광역시 서구        인천광역시 서구 석남동(신현사거리 부근)          3
# 3444   2019  스쿨존어린이    서울특별시 은평구        서울특별시 은평구 불광동(연신초교 부근)          3
# 10592  2019    보행노인    인천광역시 연수구     인천광역시 연수구 옥련동(비류대로189 부근)          3
# 11451  2016     자전거     대전광역시 중구        대전광역시 중구 태평동(태평오거리 부근)          4
# 7375   2013     자전거    부산광역시 수영구    부산광역시 수영구 남천동(광안대교대연램프 부근)          6
# 6208   2018    보행노인    서울특별시 양천구        서울특별시 양천구 신월동(중앙빌딩 부근)          5
# 6449   2023     자전거  경상북도 포항시 남구  경상북도 포항시 남구 대도동(상공회의소사거리 부근)          4
# 6322   2013    보행노인  강원특별자치도 홍천군    강원특별자치도 홍천군 홍천읍(동아미용타운 부근)          4
# 12739  2014    보행노인    서울특별시 관악구       서울특별시 관악구 봉천동(당곡사거리 부근)          5
# 6561   2014     자전거     대구광역시 북구       대구광역시 북구 서변동(서변지하차도 부근)          4
# 10437  2017     자전거  경기도 안산시 상록구    경기도 안산시 상록구 사동(한대앞역삼거리 부근)          5
# 7371   2013     자전거   부산광역시 해운대구    부산광역시 해운대구 우동(현대 카멜리아@ 부근)          4
# 13518  2013     자전거     광주광역시 북구       광주광역시 북구 용봉동(도밍고노래방 부근)          4
# 1035   2018    보행노인      경기도 파주시         경기도 파주시 법원읍(법원사거리 부근)          3
#
#              lat         lon  \
# 2554   36.075234  126.687479
# 10178  37.513494  126.673701
# 3444   37.626494  126.928409
# 10592  37.428443  126.654995
# 11451  36.326143  127.393500
# 7375   35.136858  129.110275
# 6208   37.520951  126.834943
# 6449   36.018328  129.359991
# 6322   37.688823  127.883193
# 12739  37.489073  126.927225
# 6561   35.914962  128.599715
# 10437  37.309035  126.852617
# 7371   35.157726  129.149153
# 13518  35.178366  126.896634
# 1035   37.849354  126.872916
#
#                                                  polygon
# 2554   {type:Polygon,coordinates:[[[126.68927582,36.0...
# 10178  {type:Polygon,coordinates:[[[126.67549716,37.5...
# 3444   {type:Polygon,coordinates:[[[126.93110385,37.6...
# 10592  {type:Polygon,coordinates:[[[126.65679123,37.4...
# 11451  {type:Polygon,coordinates:[[[127.39529627,36.3...
# 7375   {type:Polygon,coordinates:[[[129.1118266,35.13...
# 6208   {type:Polygon,coordinates:[[[126.83673997,37.5...
# 6449   {type:Polygon,coordinates:[[[129.36178773,36.0...
# 6322   {type:Polygon,coordinates:[[[127.8847966,37.69...
# 12739  {type:Polygon,coordinates:[[[126.9288239,37.49...
# 6561   {type:Polygon,coordinates:[[[128.6012817,35.91...
# 10437  {type:Polygon,coordinates:[[[126.85441324,37.3...
# 7371   {type:Polygon,coordinates:[[[129.1507049,35.15...
# 13518  {type:Polygon,coordinates:[[[126.8981863,35.17...
# 1035   {type:Polygon,coordinates:[[[126.87471274,37.8...

# %%
data_gr_type = data_pick.groupby('type')['accidents'].sum().reset_index(name='count')
data_gr_type = data_gr_type.sort_values(['count'], ascending = 0)
data_gr_type
# Out:
#      type  count
# 4     자전거  24939
# 1    보행노인  23165
# 0    무단횡단  14805
# 2   보행어린이   3802
# 3  스쿨존어린이    989

# %%
from IPython.display import display, HTML

# %%
data_gr_type.plot( # 차트 그리기 함수
    kind = 'pie', # 차트 유형 - 파이 
    y = 'count', # y값: count 열
    labels = data_gr_type['type'], # 각 대칭 이름: type 열 
    figsize = (10, 10), # 사이즈: 10*10 인치
    startangle = -90, # 시작 각도 위치: -90도
    autopct = '%.1f%%', # 소수점 1자리와 %로 백분율 표시
    title = '각 사고 유형별 총 발생 통계 그래프', # 제목
    cmap = matplotlib.cm.binary # 색상(회색톤)
)
plt.savefig('plottest.png')

# %%
display(HTML(f'''
    <div style='display: flex; justify-content: space-around'>
    <div style=''>{data_gr_type.to_html(index=0)}</div>
    <div><img src='plottest.png'></img></div>
    </div>
'''))
# Out:
#     <div style='display: flex; justify-content: space-around'>
#     <div style=''><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>type</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td
# 14280  {type:Polygon,coordinates:[[[126.4872876,33.49...
# 3419   {type:Polygon,coordinates:[[[129.07640894,35.2...
# 13091  {type:Polygon,coordinates:[[[126.96435952,37.5...
# 7411   {type:Polygon,coordinates:[[[127.01884496,37.5...
# 8985   {type:Polygon,coordinates:[[[129.08603478,35.2...
# 13481  {type:Polygon,coordinates:[[[127.4324411,36.35...
# 3418   {type:Polygon,coordinates:[[[126.84505526,37.4...
# 11008  {type:Polygon,coordinates:[[[126.72145786,37.5...
# 3421   {type:Polygon,coordinates:[[[129.21447996,35.2...
# 8051   {type:Polygon,coordinates:[[[127.07850998,37.2...
# 3398   {type:Polygon,coordinates:[[[129.31498136,35.5...
# 8520   {type:Polygon,coordinates:[[[127.26604463,36.5...
# 12552  {type:Polygon,coordinates:[[[127.05998454,37.0...
# 621    {type:Polygon,coordinates:[[[126.48091124,33.4...
# 10994  {type:Polygon,coordinates:[[[127.37901606,36.6...
# 8983   {type:Polygon,coordinates:[[[129.10315783,35.1...

# %%
data_fix = data_school_zone.groupby('year')['accidents'].sum().reset_index(name='count')
data_fix
# Out:
#     year  count
# 0   2012     74
# 1   2013     56
# 2   2014     90
# 3   2015     88
# 4   2016     95
# 5   2017     68
# 6   2018     87
# 7   2019     87
# 8   2020     72
# 9   2021     85
# 10  2022     89
# 11  2023     98

# %%
data_fix.plot(
    kind = 'pie',
    y = 'count',
    labels = data_fix['year'],
    figsize = (12, 15),
    startangle = 90,
    autopct = '%.1f%%',
    title = '연도별 스쿨존 어린이 사고 발생 통계',
    cmap = matplotlib.cm.GnBu
)
# plt.savefig('plottest2.png')
# Out:
# <Axes: title={'center': '연도별 스쿨존 어린이 사고 발생 통계'}, ylabel='count'>

# %%
# !pip install dash

# %%
from dash import Dash, html, dcc, callback, Output, Input
import plotly.express as px

# %%
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/gapminder_unfiltered.csv')
app = Dash()
app.layout = [
    html.H1(children='Title of Dash App', style={'textAlign':'center'}),
    dcc.Dropdown(df.country.unique(), 'Chile', id='dropdown-selection'),
    dcc.Graph(id='graph-content')
]

@callback(
    Output('graph-content', 'figure'),
    Input('dropdown-selection', 'value')
)
def update_graph(value):
    dff = df[df.country==value]
    return px.line(dff, x='year', y='pop')

if __name__ == '__main__':
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
print(pd.__all__)
# Out:
# ['ArrowDtype', 'BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Flags', 'Float32Dtype', 'Float64Dtype', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt8Dtype', 'api', 'array', 'arrays', 'bdate_range', 'concat', 'crosstab', 'cut', 'date_range', 'describe_option', 'errors', 'eval', 'factorize', 'get_dummies', 'from_dummies', 'get_option', 'infer_freq', 'interval_range', 'io', 'isna', 'isnull', 'json_normalize', 'lreshape', 'melt', 'merge', 'merge_asof', 'merge_ordered', 'notna', 'notnull', 'offsets', 'option_context', 'options', 'period_range', 'pivot', 'pivot_table', 'plotting', 'qcut', 'read_clipboard', 'read_csv', 'read_excel', 'read_feather', 'read_fwf', 'read_gbq', 'read_hdf', 'read_html', 'read_json', 'read_orc', 'read_parquet', 'read_pickle', 'read_sas', 'read_spss', 'read_sql', 'read_sql_query', 'read_sql_table', 'read_stata', 'read_table', 'read_xml', 'reset_option', 'set_eng_float_format', 'set_option', 'show_versions', 'test', 'testing', 'timedelta_range', 'to_datetime', 'to_numeric', 'to_pickle', 'to_timedelta', 'tseries', 'unique', 'value_counts', 'wide_to_long']

# %%
for t in data_gr_type['type']: # 사고 유형별 총 사고 발생량에서 type 컬럼 따오기
    data_pickx = data_pick.copy() # 객체 깊은 복사
    data_auto = data_pickx[data_pickx['type'] == t] # 각 유형(t)에 대한 데이터만 가져오기
    data_auto = data_auto.groupby('year')['accidents'].sum().reset_index(name='count').tail(10) # 이하 동일, 연도별 그룹화, 사고건수 부분합 및 인덱스 이름 지정
    data_auto.plot( # 차트 그리기
        kind = 'pie',
        y = 'count',
        labels = data_auto['year'],
        figsize = (16, 20), # 사이즈 늘림
        startangle = 90,
        autopct = '%.1f%%',
        title = f'연도별 {t} 사고 발생 통계',
        cmap = matplotlib.cm.GnBu # 색상: 라이트그린-다크블루(?)
    )

# %%
data_pick_map = data_pick2.copy()

# %%
title_array = data_gr_type['type']
map_list2 = []
for t in title_array:
    map_list2.append(data_pick_map[data_pick_map['type'] == t].groupby('region')['accidents'].sum().reset_index(name='count').sort_values(['count'], ascending = 0).head(15))

map_list2[0]
# Out:
#           region  count
# 129    서울특별시 송파구   1658
# 131   서울특별시 영등포구   1075
# 90      대구광역시 북구    973
# 87     대구광역시 달서구    952
# 122   서울특별시 동대문구    948
# 136    서울특별시 중랑구    735
# 91      대구광역시 서구    598
# 19       경기도 부천시    572
# 113    서울특별시 강동구    557
# 92     대구광역시 수성구    537
# 31   경기도 안산시 단원구    514
# 120    서울특별시 노원구    510
# 22   경기도 부천시 원미구    483
# 117    서울특별시 광진구    454
# 118    서울특별시 구로구    444

# %%
plt.figure(figsize=(15,12))
squarify.plot(
    sizes = map_list2[0]['count'],
    label = map_list2[0]['region'],
    alpha = 0.8,
    text_kwargs = {'fontsize' : 20}
)
plt.title(f'전국 TOP15 {title_array[0]} 사고다발지역')
plt.gca().invert_yaxis()
plt.show()

# %%
for t in title_array:
    data_plt_region = data_pick_map[data_pick_map['type'] == t].groupby('region')['accidents'].sum().reset_index(name='count').sort_values(['count'], ascending = 0).head(15)
    data_plt_region.plot( # 차트 그리기
        kind = 'bar',
        x = 'region',
        y = 'count',
        label = '발생건수', # data_plt_region['region'],
        figsize = (16, 20), # 사이즈 늘림
        # startangle = 90,
        title = f'전국 {t} 사고다발지역 TOP15 발생건수',
        color = 'Skyblue' # 색상: 라이트그린-다크블루(?)
    )
