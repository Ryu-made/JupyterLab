# %% [raw]
# !pip install pymongo

# %%
import pymongo

# %%
# MongoDB 커넥션 연결
conn = pymongo.MongoClient("mongodb://id330:pw330@175.126.37.21:37017/db330")

# 데이터베이스 연결
db = conn.get_database('db330')

# 컬렉션(테이블) 연결/만들기
db.drop_collection('gdp_csv')
collection = db.get_collection('gdp_csv')

# %%
# 하둡의 csv 파일 읽기
import pandas as pd
from hdfs import InsecureClient
fs = InsecureClient('http://bdata.iptime.org:9999', user='hadoop')
# 1인당 gdp
path = '/user/hadoop/sports/'
f_name = '_20250110104927.csv'
with fs.read(f'{path}{f_name}', encoding='utf-8') as reader:
    df1 = pd.read_csv(reader)

df1
# Out:
#       시점  대한민국    중국   일본   미국  브라질    페루  핀란드  프랑스   독일  스웨덴    영국  남아프리카공화국  \
# 0   2001   4.7   8.3  0.4  1.0  1.4   0.6  2.6  2.0  1.7  1.4   2.6       2.7
# 1   2002   7.7   9.1  0.0  1.7  3.1   5.5  1.7  1.1 -0.2  2.2   1.8       3.7
# 2   2003   3.1  10.0  1.5  2.8  1.1   4.2  2.0  0.8 -0.7  2.3   3.1       2.9
# 3   2004   5.2  10.1  2.2  3.8  5.8   5.0  4.0  2.8  1.2  4.3   2.4       4.6
# 4   2005   4.4  11.4  1.8  3.5  3.2   6.3  2.8  1.7  0.7  2.9   2.7       5.3
# 5   2006   5.2  12.7  1.4  2.8  4.0   7.5  4.0  2.4  3.8  4.7   2.4       5.6
# 6   2007   5.8  14.2  1.5  2.0  6.1   8.5  5.3  2.4  3.0  3.4   2.6       5.4
# 7   2008   3.0   9.7 -1.2  0.1  5.1   9.1  0.8  0.3  1.0 -0.5  -0.2       3.2
# 8   2009   0.8   9.4 -5.7 -2.6 -0.1   1.1 -8.1 -2.9 -5.7 -4.3  -4.6      -1.5
# 9   2010   7.0  10.6  4.1  2.7  7.5   8.3  3.2  1.9  4.2  6.0   2.2       3.0
# 10  2011   3.7   9.6  0.0  1.6  4.0   6.3  2.5  2.2  3.9  3.2   1.1       3.2
# ...

# %%
df1.rename(columns={"시점":"year", 
                    "대한민국":"korea", 
                    "중국":"china", 
                    "일본":"japan", 
                    "미국":"usa", 
                    "브라질":"brazil", 
                    "페루":"peru", 
                    "핀란드":"finland", 
                    "프랑스":"france", 
                    "독일":"germany", 
                    "스웨덴":"sweden", 
                    "영국":"england", 
                    "남아프리카공화국":"southAfrica", 
                    "오스트레일리아":"australia"
                   }, inplace=True)
df1.head(2)
# Out:
#    year  korea  china  japan  usa  brazil  peru  finland  france  germany  \
# 0  2001    4.7    8.3    0.4  1.0     1.4   0.6      2.6     2.0      1.7
# 1  2002    7.7    9.1    0.0  1.7     3.1   5.5      1.7     1.1     -0.2
#
#    sweden  england  southAfrica  australia
# 0     1.4      2.6          2.7        2.0
# 1     2.2      1.8          3.7        4.0

# %%
# 컬렉션에 DataFrame 형식 데이터 입력
collection.insert_many(df1.to_dict(orient='records'))
# Out:
# InsertManyResult([ObjectId('679193a47fd85c8616659c2b'), ObjectId('679193a47fd85c8616659c2c'), ObjectId('679193a47fd85c8616659c2d'), ObjectId('679193a47fd85c8616659c2e'), ObjectId('679193a47fd85c8616659c2f'), ObjectId('679193a47fd85c8616659c30'), ObjectId('679193a47fd85c8616659c31'), ObjectId('679193a47fd85c8616659c32'), ObjectId('679193a47fd85c8616659c33'), ObjectId('679193a47fd85c8616659c34'), ObjectId('679193a47fd85c8616659c35'), ObjectId('679193a47fd85c8616659c36'), ObjectId('679193a47fd85c8616659c37'), ObjectId('679193a47fd85c8616659c38'), ObjectId('679193a47fd85c8616659c39'), ObjectId('679193a47fd85c8616659c3a'), ObjectId('679193a47fd85c8616659c3b'), ObjectId('679193a47fd85c8616659c3c'), ObjectId('679193a47fd85c8616659c3d'), ObjectId('679193a47fd85c8616659c3e'), ObjectId('679193a47fd85c8616659c3f'), ObjectId('679193a47fd85c8616659c40'), ObjectId('679193a47fd85c8616659c41')], acknowledged=True)

# %%
fs = InsecureClient('http://bdata.iptime.org:9999', user='hadoop')
path = '/user/hadoop/sports/'
# 생활체육 참여율
f_name = '규칙적_체육활동_참여율_주_1회_이상__연도별_비교_20250114092534.csv'
with fs.read(f'{path}{f_name}', encoding='euc-kr') as reader:
    df2 = pd.read_csv(reader)

# 컬렉션(테이블) 연결/만들기
collection2 = db.get_collection('rate_csv')
# DateFrame 형식의 데이터 입력
collection2.insert_many(df2.to_dict(orient='records'))
print('컬렉션에 데이터 입력 완료')

# %%
# 입력된 데이터 전체 확인
result = collection.find({},{'_id':0})
for row in result:
    print(row)
# Out:
# {'시점': 2001, '대한민국': 4.7, '중국': 8.3, '일본': 0.4, '미국': 1.0, '브라질': 1.4, '페루': 0.6, '핀란드': 2.6, '프랑스': 2.0, '독일': 1.7, '스웨덴': 1.4, '영국': 2.6, '남아프리카공화국': 2.7, '오스트레일리아': 2.0}
# {'시점': 2002, '대한민국': 7.7, '중국': 9.1, '일본': 0.0, '미국': 1.7, '브라질': 3.1, '페루': 5.5, '핀란드': 1.7, '프랑스': 1.1, '독일': -0.2, '스웨덴': 2.2, '영국': 1.8, '남아프리카공화국': 3.7, '오스트레일리아': 4.0}
# {'시점': 2003, '대한민국': 3.1, '중국': 10.0, '일본': 1.5, '미국': 2.8, '브라질': 1.1, '페루': 4.2, '핀란드': 2.0, '프랑스': 0.8, '독일': -0.7, '스웨덴': 2.3, '영국': 3.1, '남아프리카공화국': 2.9, '오스트레일리아': 3.1}
# {'시점': 2004, '대한민국': 5.2, '중국': 10.1, '일본': 2.2, '미국': 3.8, '브라질': 5.8, '페루': 5.0, '핀란드': 4.0, '프랑스': 2.8, '독일': 1.2, '스웨덴': 4.3, '영국': 2.4, '남아프리카공화국': 4.6, '오스트레일리아': 4.2}
# {'시점': 2005, '대한민국': 4.4, '중국': 11.4, '일본': 1.8, '미국': 3.5, '브라질': 3.2, '페루': 6.3, '핀란드': 2.8, '프랑스': 1.7, '독일': 0.7, '스웨덴': 2.9, '영국': 2.7, '남아프리카공화국': 5.3, '오스트레일리아': 3.2}
# ...

# %%
# 입력된 데이터 전체 확인
result = collection.find()
# collection.find()
print(type(result)) 
print(result)
for row in result:
    print(row)
# Out:
# <class 'pymongo.synchronous.cursor.Cursor'>
# ...
# {'_id': ObjectId('6790a21b0c883b54957c3381'), '시점': 2001, '대한민국': 4.7, '중국': 8.3, '일본': 0.4, '미국': 1.0, '브라질': 1.4, '페루': 0.6, '핀란드': 2.6, '프랑스': 2.0, '독일': 1.7, '스웨덴': 1.4, '영국': 2.6, '남아프리카공화국': 2.7, '오스트레일리아': 2.0}
# {'_id': ObjectId('6790a21b0c883b54957c3382'), '시점': 2002, '대한민국': 7.7, '중국': 9.1, '일본': 0.0, '미국': 1.7, '브라질': 3.1, '페루': 5.5, '핀란드': 1.7, '프랑스': 1.1, '독일': -0.2, '스웨덴': 2.2, '영국': 1.8, '남아프리카공화국': 3.7, '오스트레일리아': 4.0}
# {'_id': ObjectId('6790a21b0c883b54957c3383'), '시점': 2003, '대한민국': 3.1, '중국': 10.0, '일본': 1.5, '미국': 2.8, '브라질': 1.1, '페루': 4.2, '핀란드': 2.0, '프랑스': 0.8, '독일': -0.7, '스웨덴': 2.3, '영국': 3.1, '남아프리카공화국': 2.9, '오스트레일리아': 3.1}
# {'_id': ObjectId('6790a21b0c883b54957c3384'), '시점': 2004, '대한민국': 5.2, '중국': 10.1, '일본': 2.2, '미국': 3.8, '브라질': 5.8, '페루': 5.0, '핀란드': 4.0, '프랑스': 2.8, '독일': 1.2, '스웨덴': 4.3, '영국': 2.4, '남아프리카공화국': 4.6, '오스트레일리아': 4.2}
# ...

# %% [raw]
# #  $eq  (equals) 주어진 값과 일치하는 값
# #  $gt  (greater than) 주어진 값보다 큰 값
# #  $gte  (greater than or equals) 주어진 값보다 크거나 같은 값
# #  $lt  (less than) 주어진 값보다 작은 값
# #  $lte  (less then or equals) 주어진 값보다 작거나 같은 값
# #  $ne  (not equlas) 주어진 값과 일치하지 않는 값
# #  $in  (in) 주어진 배열 안에 속하는 값
# #  $nin  (not in) 주어진 배열 안에 속하지 않는 값
#
# # age필드의 값이 10보다 크고 30보다 작은 값 조회
# data1 = collection.find({'age' : {'$gt':10, '$lt':34}},{'_id':0}) #가져오기
# for i in data1:
#     print(i)
#
# # id가 pyaa 이고 나이가 33인 것 출력
# data1 = collection.find({'$and' : [{'id':'pyaa'}, {'age':33}]},{'_id':0}) #가져오기
# for i in data1:
#     print(i)

# %%
# 조건식으로 데이터 확인
result2 = collection.find({'$and': [ {'일본': {'$lt':1}}, {'시점': {'$lte':2018}} ]}, {'_id':0, '대한민국':0}) # 조건식으로 가져오기
for row in result2:
    print(row)
# Out:
# {'시점': 2001, '중국': 8.3, '일본': 0.4, '미국': 1.0, '브라질': 1.4, '페루': 0.6, '핀란드': 2.6, '프랑스': 2.0, '독일': 1.7, '스웨덴': 1.4, '영국': 2.6, '남아프리카공화국': 2.7, '오스트레일리아': 2.0}
# {'시점': 2002, '중국': 9.1, '일본': 0.0, '미국': 1.7, '브라질': 3.1, '페루': 5.5, '핀란드': 1.7, '프랑스': 1.1, '독일': -0.2, '스웨덴': 2.2, '영국': 1.8, '남아프리카공화국': 3.7, '오스트레일리아': 4.0}
# {'시점': 2008, '중국': 9.7, '일본': -1.2, '미국': 0.1, '브라질': 5.1, '페루': 9.1, '핀란드': 0.8, '프랑스': 0.3, '독일': 1.0, '스웨덴': -0.5, '영국': -0.2, '남아프리카공화국': 3.2, '오스트레일리아': 3.6}
# {'시점': 2009, '중국': 9.4, '일본': -5.7, '미국': -2.6, '브라질': -0.1, '페루': 1.1, '핀란드': -8.1, '프랑스': -2.9, '독일': -5.7, '스웨덴': -4.3, '영국': -4.6, '남아프리카공화국': -1.5, '오스트레일리아': 1.9}
# {'시점': 2011, '중국': 9.6, '일본': 0.0, '미국': 1.6, '브라질': 4.0, '페루': 6.3, '핀란드': 2.5, '프랑스': 2.2, '독일': 3.9, '스웨덴': 3.2, '영국': 1.1, '남아프리카공화국': 3.2, '오스트레일리아': 2.4}
# {'시점': 2014, '중국': 7.4, '일본': 0.3, '미국': 2.5, '브라질': 0.5, '페루': 2.4, '핀란드': -0.4, '프랑스': 1.0, '독일': 2.2, '스웨덴': 2.7, '영국': 3.2, '남아프리카공화국': 1.4, '오스트레일리아': 2.6}
# ...
